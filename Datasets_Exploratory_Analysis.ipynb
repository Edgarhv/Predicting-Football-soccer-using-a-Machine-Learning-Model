# %%
import pandas as pd
import numpy as np

# %%
# Load Databases
fd = 'D:\Descargas\Proyecto Final\Resources'
appearances = f'{fd}/appearances.csv'
clubs = f'{fd}/clubs.csv'
competitions = f'{fd}/competitions.csv'
games = f'{fd}/games.csv'
players = f'{fd}/players.csv'
top250 = f'{fd}/top250.csv'

# %%
appearances_df = pd.read_csv(appearances)
appearances_df.head()
# Out:
#    player_id  game_id   appearance_id competition_id  player_club_id  goals  \
# 0     410184  2602706  2602706_410184           UKR1            6994      0
# 1      84938  2581152   2581152_84938             L1               3      0
# 2      84938  2581178   2581178_84938             L1               3      0
# 3      84938  2581188   2581188_84938             L1               3      0
# 4      84938  2581196   2581196_84938             L1               3      0
#
#    assists  minutes_played  yellow_cards  red_cards
# 0        0              45             0          0
# 1        0              90             0          0
# 2        0              90             0          0
# 3        0              90             0          0
# 4        0              90             0          0

# %%
clubs_df = pd.read_csv(clubs)
clubs_df.head()
# Out:
#    club_id                           name                    pretty_name  \
# 0     6996               goverla-uzhgorod               Goverla Uzhgorod
# 1     6994  metalurg-zaporizhya-bis-2016-  Metalurg Zaporizhya Bis 2016
# 2     7185          panthrakikos-komotini          Panthrakikos Komotini
# 3     3216              mersin-idmanyurdu              Mersin Idmanyurdu
# 4    28956                    ael-kalloni                    Ael Kalloni
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                    UKR1                 NaN           0          0.0
# 1                    UKR1                 NaN           0          0.0
# 2                     GR1                23.0           5         26.3
# 3                     TR1                 NaN           0          0.0
# 4                     GR1                 NaN           0          0.0
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# ...

# %%
competitions_df = pd.read_csv(competitions)
competitions_df.head()
# Out:
#   competition_id             name                type  country_id  \
# 0             L1       bundesliga          first_tier          40
# 1            DFB        dfb-pokal        domestic_cup          40
# 2            DFL     dfl-supercup  domestic_super_cup          40
# 3            NL1       eredivisie          first_tier         122
# 4            NLP  toto-knvb-beker        domestic_cup         122
#
#   country_name domestic_league_code confederation  \
# 0      Germany                   L1        europa
# 1      Germany                   L1        europa
# 2      Germany                   L1        europa
# 3  Netherlands                  NL1        europa
# 4  Netherlands                  NL1        europa
#
#                                                  url
# 0  https://www.transfermarkt.co.uk/bundesliga/sta...
# 1  https://www.transfermarkt.co.uk/dfb-pokal/star...
# 2  https://www.transfermarkt.co.uk/dfl-supercup/s...
# ...

# %%
games_df = pd.read_csv(games)
games_df.head()
# Out:
#    game_id competition_code  season        round        date  home_club_id  \
# 0  2581147               L1    2015  1. Matchday  2015-08-14            27
# 1  2576512              DFL    2015        Final  2015-08-01            82
# 2  2581181               L1    2015  2. Matchday  2015-08-22           533
# 3  2581179               L1    2015  2. Matchday  2015-08-22            42
# 4  2581178               L1    2015  2. Matchday  2015-08-22             3
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 0            41                5                0                 1.0
# 1            27                6                5                 NaN
# 2            27                1                2                16.0
# 3            15                0                1                13.0
# 4            82                1                1                 5.0
#
#    away_club_position              stadium  attendance  \
# ...

# %%
players_df = pd.read_csv(players)
players_df.head()
# Out:
#    player_id  current_club_id                 name          pretty_name  \
# 0     257767             4795        aloy-ihenacho        Aloy Ihenacho
# 1     320889             4795      thomas-blomeyer      Thomas Blomeyer
# 2      42318             4795     konstantin-engel     Konstantin Engel
# 3      94598             4795  stefan-wannenwetsch  Stefan Wannenwetsch
# 4     381921             6994          ivan-komlev          Ivan Komlev
#
#   country_of_birth country_of_citizenship date_of_birth  position  \
# 0          Nigeria                Nigeria    1995-07-21    Attack
# 1          Germany                Germany    1996-04-24  Defender
# 2            UdSSR             Kazakhstan    1988-07-27  Defender
# 3          Germany                Germany           NaN  Midfield
# 4              NaN                Ukraine    1994-07-22  Defender
#
#          sub_position   foot  height_in_cm  \
# 0      Centre-Forward   Left           182
# 1         Centre-Back   Both           191
# ...

# %%
df_list = [appearances_df, clubs_df, competitions_df, games_df, players_df]
name_list = ["appearances_df", "clubs_df", "competitions_df", "games_df", "players_df"]
for i in range(len(name_list)):
    print(f'{name_list[i].upper()} has columns with NaN values:')
    print(df_list[i].isna().sum())
    print(" ")
# Out:
# APPEARANCES_DF has columns with NaN values:
# player_id         0
# game_id           0
# appearance_id     0
# competition_id    0
# player_club_id    0
# goals             0
# assists           0
# minutes_played    0
# yellow_cards      0
# red_cards         0
# dtype: int64
#
# CLUBS_DF has columns with NaN values:
# club_id                     0
# name                        0
# pretty_name                 0
# domestic_competition_id     0
# total_market_value         18
# squad_size                  0
# average_age                 0
# foreigners_number           0
# foreigners_percentage      27
# national_team_players       0
# stadium_name                0
# stadium_seats               0
# net_transfer_record         0
# coach_name                  0
# url                         0
# dtype: int64
#
# COMPETITIONS_DF has columns with NaN values:
# competition_id          0
# name                    0
# type                    0
# country_id              0
# ...

# %%
players_df.describe()
# Out:
#            player_id  current_club_id  height_in_cm
# count   20626.000000     20626.000000  20626.000000
# mean   289222.910889      4145.085378    172.197227
# std    203292.082994      9223.325976     42.135029
# min        10.000000         3.000000      0.000000
# 25%    111058.750000       383.000000    176.000000
# 50%    265527.500000      1050.000000    182.000000
# 75%    422451.250000      2999.000000    187.000000
# max    949337.000000     61825.000000    206.000000

# %%
players_df.dtypes
# Out:
# player_id                  int64
# current_club_id            int64
# name                      object
# pretty_name               object
# country_of_birth          object
# country_of_citizenship    object
# date_of_birth             object
# position                  object
# sub_position              object
# foot                      object
# height_in_cm               int64
# url                       object
# dtype: object

# %%
# Dropping NaN values from columns of interest (Appereances, Clubs and Players)
players_df.dropna()
appearances_df.dropna()
clubs_df.dropna()
games_df #2021 filtro
# Print new shape
print(appearances_df.shape)
print(players_df.shape)
print(clubs_df.shape)
# Out:
# (820242, 10)
# (20626, 12)
# (364, 15)

# %%
# 2018 games are 5641
games_df[games_df["season"] == 2018].count()
# Out:
# game_id               5641
# competition_code      5641
# season                5641
# round                 5641
# date                  5641
# home_club_id          5641
# away_club_id          5641
# home_club_goals       5641
# away_club_goals       5641
# home_club_position    3986
# away_club_position    3986
# stadium               5631
# attendance            5305
# url                   5641
# dtype: int64

# %%
# Adding new dataset in order to obtain the market value of each players
top250_df = pd.read_csv(top250)
top250_df
# Out:
#                    Name            Position  Age       Team_from  \
# 0             Luís Figo        Right Winger   27    FC Barcelona
# 1         Hernán Crespo      Centre-Forward   25           Parma
# 2         Marc Overmars         Left Winger   27         Arsenal
# 3     Gabriel Batistuta      Centre-Forward   31      Fiorentina
# 4        Nicolas Anelka      Centre-Forward   21     Real Madrid
# ...                 ...                 ...  ...             ...
# 4695      Jasmin Kurtic  Attacking Midfield   29        Atalanta
# 4696          Tchê Tchê    Central Midfield   25       Palmeiras
# 4697      Silvan Widmer          Right-Back   25  Udinese Calcio
# 4698         Yuya Osako      Second Striker   28      1. FC Köln
# 4699       Kyle Bartley         Centre-Back   27         Swansea
#
#          League_from        Team_to     League_to     Season  Market_value  \
# 0             LaLiga    Real Madrid        LaLiga  2000-2001           NaN
# ...

# %%
top250_df.dtypes
# Out:
# Name             object
# Position         object
# Age               int64
# Team_from        object
# League_from      object
# Team_to          object
# League_to        object
# Season           object
# Market_value    float64
# Transfer_fee      int64
# dtype: object

# %%
top250_df.isnull().sum()
# Out:
# Name               0
# Position           0
# Age                0
# Team_from          0
# League_from        0
# Team_to            0
# League_to          0
# Season             0
# Market_value    1260
# Transfer_fee       0
# dtype: int64

# %%
# Dropping NaN values
top250_NaN = top250_df.dropna()
top250_NaN
# Out:
#                      Name            Position  Age       Team_from  \
# 999          Carlos Tévez      Second Striker   20    Boca Juniors
# 1001       Valeri Bojinov      Centre-Forward   18           Lecce
# 1004         Jiri Jarosik         Centre-Back   27     CSKA Moscow
# 1009  Jean-Alain Boumsong         Centre-Back   25         Rangers
# 1011       Nicolas Anelka      Centre-Forward   25        Man City
# ...                   ...                 ...  ...             ...
# 4695        Jasmin Kurtic  Attacking Midfield   29        Atalanta
# 4696            Tchê Tchê    Central Midfield   25       Palmeiras
# 4697        Silvan Widmer          Right-Back   25  Udinese Calcio
# 4698           Yuya Osako      Second Striker   28      1. FC Köln
# 4699         Kyle Bartley         Centre-Back   27         Swansea
#
#          League_from        Team_to       League_to     Season  Market_value  \
# 999        Argentina    Corinthians         Série A  2004-2005    15000000.0
# ...

# %%
# Counting athletes per season
top250_NaN["Season"].value_counts()
# Out:
# 2016-2017    249
# 2011-2012    248
# 2015-2016    248
# 2013-2014    248
# 2009-2010    247
# 2012-2013    246
# 2014-2015    245
# 2008-2009    243
# 2018-2019    242
# 2010-2011    241
# 2017-2018    241
# 2007-2008    235
# 2006-2007    229
# 2005-2006    219
# 2004-2005     59
# Name: Season, dtype: int64

# %%
# 241 athletes in the 2017-2018 season
top250_NaN[top250_NaN['Season'] == "2017-2018"]
# Out:
#                    Name            Position  Age       Team_from  \
# 4211             Neymar         Left Winger   25    FC Barcelona
# 4212  Philippe Coutinho  Attacking Midfield   25       Liverpool
# 4213    Ousmane Dembélé        Right Winger   20   Bor. Dortmund
# 4214      Romelu Lukaku      Centre-Forward   24         Everton
# 4215    Virgil van Dijk         Centre-Back   26     Southampton
# ...                 ...                 ...  ...             ...
# 4450     Diego Llorente         Centre-Back   23     Real Madrid
# 4451      Clinton N'Jie      Centre-Forward   23           Spurs
# 4452            Marcelo         Centre-Back   30        Besiktas
# 4453         Jorge Meré         Centre-Back   20  Sporting Gijón
# 4454    Víctor Camarasa    Central Midfield   23      Levante UD
#
#          League_from         Team_to       League_to     Season  Market_value  \
# 4211          LaLiga        Paris SG         Ligue 1  2017-2018   100000000.0
# ...

# %%
# 242 athletes in the 2018-2019 season
top250_NaN[top250_NaN['Season'] == "2018-2019"]
# Out:
#                    Name            Position  Age       Team_from  \
# 4455      Kylian Mbappé        Right Winger   19          Monaco
# 4456  Cristiano Ronaldo      Centre-Forward   33     Real Madrid
# 4457       Thomas Lemar         Left Winger   22          Monaco
# 4458       Riyad Mahrez        Right Winger   27       Leicester
# 4459            Alisson          Goalkeeper   25         AS Roma
# ...                 ...                 ...  ...             ...
# 4695      Jasmin Kurtic  Attacking Midfield   29        Atalanta
# 4696          Tchê Tchê    Central Midfield   25       Palmeiras
# 4697      Silvan Widmer          Right-Back   25  Udinese Calcio
# 4698         Yuya Osako      Second Striker   28      1. FC Köln
# 4699       Kyle Bartley         Centre-Back   27         Swansea
#
#          League_from          Team_to       League_to     Season  \
# 4455         Ligue 1         Paris SG         Ligue 1  2018-2019
# ...

# %%
# 483 in both seasons
top250_2018 = top250_NaN[(top250_NaN['Season'] == "2017-2018") | (top250_NaN['Season'] == "2018-2019")]
top250_2018
# Out:
#                    Name            Position  Age       Team_from  \
# 4211             Neymar         Left Winger   25    FC Barcelona
# 4212  Philippe Coutinho  Attacking Midfield   25       Liverpool
# 4213    Ousmane Dembélé        Right Winger   20   Bor. Dortmund
# 4214      Romelu Lukaku      Centre-Forward   24         Everton
# 4215    Virgil van Dijk         Centre-Back   26     Southampton
# ...                 ...                 ...  ...             ...
# 4695      Jasmin Kurtic  Attacking Midfield   29        Atalanta
# 4696          Tchê Tchê    Central Midfield   25       Palmeiras
# 4697      Silvan Widmer          Right-Back   25  Udinese Calcio
# 4698         Yuya Osako      Second Striker   28      1. FC Köln
# 4699       Kyle Bartley         Centre-Back   27         Swansea
#
#          League_from        Team_to       League_to     Season  Market_value  \
# 4211          LaLiga       Paris SG         Ligue 1  2017-2018   100000000.0
# ...

# %%
# Merging games_df and appearances_df in order and filtering by 2018 season
df_2018 = pd.merge(games_df, appearances_df, how="inner", on=["game_id", "game_id"])
df_2018 = df_2018.loc[df_2018["season"] == 2018]
df_2018
# Out:
#         game_id competition_code  season                 round        date  \
# 391397  3055009             NLSC    2018                 Final  2018-08-04
# 391398  3055009             NLSC    2018                 Final  2018-08-04
# 391399  3055009             NLSC    2018                 Final  2018-08-04
# 391400  3055009             NLSC    2018                 Final  2018-08-04
# 391401  3055009             NLSC    2018                 Final  2018-08-04
# ...         ...              ...     ...                   ...         ...
# 636021  3223001              ELQ    2018  Second Round 1st leg  2019-07-25
# 636022  3223001              ELQ    2018  Second Round 1st leg  2019-07-25
# 636023  3223001              ELQ    2018  Second Round 1st leg  2019-07-25
# 636024  3223001              ELQ    2018  Second Round 1st leg  2019-07-25
# 636025  3223001              ELQ    2018  Second Round 1st leg  2019-07-25
#
# ...

# %%
len(df_2018["player_id"].unique())
# Out:
# 7088

# %%
# Merging players_df and df_2018 
players_2018 = pd.merge(players_df, df_2018, how="inner", on=["player_id", "player_id"])
players_2018
# Out:
#         player_id  current_club_id            name     pretty_name  \
# 0           39426               42  nicolai-muller  Nicolai Muller
# 1           39426               42  nicolai-muller  Nicolai Muller
# 2           39426               42  nicolai-muller  Nicolai Muller
# 3           39426               42  nicolai-muller  Nicolai Muller
# 4           39426               42  nicolai-muller  Nicolai Muller
# ...           ...              ...             ...             ...
# 129521       7161               18   jonas-hofmann   Jonas Hofmann
# 129522       7161               18   jonas-hofmann   Jonas Hofmann
# 129523       7161               18   jonas-hofmann   Jonas Hofmann
# 129524       7161               18   jonas-hofmann   Jonas Hofmann
# 129525       7161               18   jonas-hofmann   Jonas Hofmann
#
#        country_of_birth country_of_citizenship date_of_birth  position  \
# 0               Germany                Germany    1987-09-25  Midfield
# ...

# %%
players_2018.rename(columns={"pretty_name": "Name"}, inplace=True)
players_2018
# Out:
#         player_id  current_club_id            name            Name  \
# 0           39426               42  nicolai-muller  Nicolai Muller
# 1           39426               42  nicolai-muller  Nicolai Muller
# 2           39426               42  nicolai-muller  Nicolai Muller
# 3           39426               42  nicolai-muller  Nicolai Muller
# 4           39426               42  nicolai-muller  Nicolai Muller
# ...           ...              ...             ...             ...
# 129521       7161               18   jonas-hofmann   Jonas Hofmann
# 129522       7161               18   jonas-hofmann   Jonas Hofmann
# 129523       7161               18   jonas-hofmann   Jonas Hofmann
# 129524       7161               18   jonas-hofmann   Jonas Hofmann
# 129525       7161               18   jonas-hofmann   Jonas Hofmann
#
#        country_of_birth country_of_citizenship date_of_birth  position  \
# 0               Germany                Germany    1987-09-25  Midfield
# ...

# %%
market_value_2018 = pd.merge(top250_2018, players_2018, how="inner", on=["Name", "Name"])
market_value_2018
# Out:
#             Name        Position  Age     Team_from   League_from  \
# 0         Neymar     Left Winger   25  FC Barcelona        LaLiga
# 1         Neymar     Left Winger   25  FC Barcelona        LaLiga
# 2         Neymar     Left Winger   25  FC Barcelona        LaLiga
# 3         Neymar     Left Winger   25  FC Barcelona        LaLiga
# 4         Neymar     Left Winger   25  FC Barcelona        LaLiga
# ...          ...             ...  ...           ...           ...
# 9304  Yuya Osako  Second Striker   28    1. FC Köln  2.Bundesliga
# 9305  Yuya Osako  Second Striker   28    1. FC Köln  2.Bundesliga
# 9306  Yuya Osako  Second Striker   28    1. FC Köln  2.Bundesliga
# 9307  Yuya Osako  Second Striker   28    1. FC Köln  2.Bundesliga
# 9308  Yuya Osako  Second Striker   28    1. FC Köln  2.Bundesliga
#
#             Team_to     League_to     Season  Market_value  Transfer_fee  ...  \
# 0          Paris SG       Ligue 1  2017-2018   100000000.0     222000000  ...
# ...

# %%
len(market_value_2018["Name"].unique())
# Out:
# 307

# %%
# Get the total unique players in 2018
print(len(players_2018["pretty_name"].unique())) #20,290
unique_players_2018 = players_2018["pretty_name"].unique()
# Out:
# 7024

# %%
unique_players_2018
# Out:
# array(['Nicolai Muller', 'Julian Korb', 'Pirmin Schwegler', ...,
#        'Marcel Halstenberg', 'Philipp Tschauner', 'Jonas Hofmann'],
#       dtype=object)

# %%
if "Aloy Ihenacho" in unique_players_2018:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
# Unique players in both lists
list_player_names = players_df["pretty_name"].tolist()

counter = 0
for name in list_player_names:
    if name in top250_2018["Name"].tolist():
        counter += 1
    else:
        counter = counter
print(counter)
# Out:
# 365

# %%
len(list_player_names)
# Out:
# 20626

# %%
# Unique players in 2018 in both lists
x = 0
for name in unique_players_2018:
    if name in names:
        x += 1
    else:
        x = x
x
# Out:
# 307
